# %% [markdown]
# ___
# # <font color= #003366> **Segundo Examen Parcial** </font>
# - <Strong> Integrantes: </Strong>  <font color="blue">` Mónica Ibarra Herrera, Carlos Moreno Labrador, Oscar Rocha Hernández` </font>
# - <Strong> Materia: </Strong>  <font color="blue">`Modelos No Lineales Para Pronósticos` </font>
#
# <div style="display: flex; align-items: center;">
#     <div style="flex: 1;">
#         <img src="https://oci02.img.iteso.mx/Identidades-De-Instancia/ITESO/Logos%20ITESO/Logo-ITESO-Principal.jpg" width="300">
#     </div>
# </div>
#
# ___

# %% [markdown]
# ## <font color= #003366> **Descripción del commodity** </font>

# %% [markdown]
# ## <font color= #003366> **FFNN** </font>

# %% [markdown]
# ## <font color= #003366> **GARCH** </font>
